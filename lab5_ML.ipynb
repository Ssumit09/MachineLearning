# %%
import pandas as pd

# %%
df=pd.read_excel(r"C:\Users\sumit\Downloads\questions_answers.xlsx")
df
# Out:
#                                              Question  \
# 0   In what scenario should I use mean and where s...
# 1         What is covariance and what is correlation?
# 2   What does a correlation of 0 versus a correlat...
# 3   Can you name 1 classifier which is probabilist...
# 4   How would you go about designing a speech reco...
# 5   Where do we use windowing functions? What is i...
# 6   What are the different window functions you kn...
# 7                        Which one is better and why?
# 8                            What is the spectrogram?
# 9                                       what is MFCC?
# 10                     Why do we use Mel frequencies?
# 11   What is the determinant of a rectangular matrix?
# 12  Suppose you have a square matrix which is an i...
# 13  What would be the determinant of a square matr...
# 14  Why you have to take zero into something you c...
# 15                                  What is encoding?
# 16                           Can you give an example?
# 17                              Where do we use MFCC?
# 18  Can you go into little more details about the ...
# 19                      What is spectral subtraction?
# 20                               What is convolution?
# 21  What are the different kinds of convolution fu...
# 22                        What is vanishing gradient?
# 23  Does vanishing gradient happen for every netwo...
# 24     How is vanishing gradient addressed in ReLU?\t
# 25            Do you know any sequential classifiers?
# 26                     What is the full form of LSTM?
# 27           What is the mean and what is the median?
#
#                                                Answer  Strength_N Strength
# 0             Mean is used to calculate the average.           -1      Low
# 1   Correlation measures the strength and directio...           1     High
# 2   The respondent did not provide an explanation ...          -1      Low
# 3          Naive Bayes is a probabilistic classifier.           1     High
# 4   Collect a dataset, extract features, and selec...           0   Medium
# 5    I think windowing is commonly used in signal ...           0   Medium
# 6   What are the different window functions you kn...          -1      Low
# 7                                    I don't know sir          -1      Low
# 8                            Sorry sir. I don't know.          -1      Low
# 9   Mel Frequency Cepstrum Coefficients. Mel frequ...           1     High
# 10  Particularly, we use them in speech recognitio...           1     High
# 11  Determinant is calculated only for square matr...           1     High
# 12  he determinant is always one for any n by n ma...           1     High
# 13  Like for one column, if it is 0 if we found th...           1     High
# 14  So so like if we take for non zero values like...           0   Medium
# 15  So basically like encoding, it transforms the ...           0   Medium
# 16  Like there are few techniques like MFCC. It co...           0   Medium
# 17  So it is like it can be used for data compress...           0   Medium
# 18   Since you told it's a noisy environment. Like...           0   Medium
# 19  So it's a common it's like a basically like a ...           0   Medium
# 20  Sir evolution is nothing, but it's a multiplic...           0   Medium
# 21  Like there are dimensional convolutions are li...           0   Medium
# 22  Sir, the vanishing gradients are when we are b...           0   Medium
# 23  It occurs depending on the activation function...           1     High
# 24  ReLU addresses vanishing gradients by setting ...           1     High
# 25              Service sequential like LSTM and RNN.           1     High
# 26             Sir long short term memory, Sir. LSTM.           1     High
# 27  Mean is the sum of all values divided by the t...           1     High

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import OneHotEncoder
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error

# %%
X = df.drop(columns=['Strength_N','Strength'])  # Features (all columns except the target)
y = df['Strength_N']  # Target (the column you're predicting)

# %%
encoder = OneHotEncoder(sparse=False)  # sparse=False to get a dense array

# Apply the encoder to all columns (if all are categorical)
X_encoded = encoder.fit_transform(X)

# Step 4: Split the encoded data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)
# Out:
# D:\Anaconda\Lib\site-packages\sklearn\preprocessing\_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression().fit(X_train, y_train)   # Train the model with LogisticRegression for classification
y_train_pred = reg.predict(X_train)   # Predict on the training data

y_train_pred
# Out:
# array([ 1.11022302e-16,  3.33066907e-16,  1.00000000e+00,  1.00000000e+00,
#         4.71844785e-16,  1.00000000e+00, -2.77555756e-17, -7.21644966e-16,
#        -1.00000000e+00, -1.94289029e-16,  1.00000000e+00,  1.00000000e+00,
#         1.00000000e+00,  1.00000000e+00,  1.66533454e-16,  1.00000000e+00,
#        -1.11022302e-16, -1.00000000e+00,  1.00000000e+00, -3.33066907e-16,
#         3.88578059e-16, -1.00000000e+00])

# %%
import numpy as np
# MSE (Mean Squared Error)
mse_train = mean_squared_error(y_train, y_train_pred)
# RMSE (Root Mean Squared Error)
rmse_train = np.sqrt(mse_train)
# MAPE (Mean Absolute Percentage Error)
mape_train = np.mean(np.abs((y_train - y_train_pred) / y_train)) * 100

# R2 Score
r2_train = r2_score(y_train, y_train_pred)
# R² Score: This value tells you how well the model explains the variability of the target variable. A higher R² indicates a better fit.
# Display the metrics
print(f"Training Data - MSE: {mse_train}, RMSE: {rmse_train}, MAPE: {mape_train}, R2: {r2_train}")
# Out:
# Training Data - MSE: 2.251937358609875e-31, RMSE: 4.74545820612707e-16, MAPE: inf, R2: 1.0
